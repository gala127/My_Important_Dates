# %% [markdown]
# <a href="https://colab.research.google.com/github/gala127/My_Important_Dates/blob/master/C%D0%BE%D0%B7%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_%D0%B8_%D0%B4%D0%BE%D0%BF%D0%BE%D0%BB%D0%BD%D0%B5%D0%BD%D0%B8%D0%B5_%D0%B1%D0%B0%D0%B7%D1%8B_%D0%BA%D0%BB%D0%B8%D0%B5%D0%BD%D1%82%D0%BE%D0%B2_%D0%A1%D1%83%D1%80%D0%BA%D0%BE%D0%B2%D0%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#This script will create a PostgreSQL table with restricted fields for clients, specifically for storing nickname and password.
# !pip uninstall psycopg2
#python
# !pip install psycopg2

import psycopg2

# Connect to the PostgreSQL database (should be real port number)
conn = psycopg2.connect(
    dbname="Surkov_works",
    user="your_username",
    password="your_password",
    host="127.0.0.1",
    port="5432"
)

# Create a cursor object
cur = conn.cursor()
#This script will create a PostgreSQL table with restricted fields for clients, specifically for storing nickname and password.

#python

import psycopg2

# Connect to the PostgreSQL database (should be real port number)
conn = psycopg2.connect(
    dbname="Surkov_works",
    user="your_username",
    password="your_password",
    host="127.0.0.1", #local_host",
    port="5432"
)

# Create a cursor object
cur = conn.cursor()
#This script will create a PostgreSQL table with restricted fields for clients, specifically for storing nickname and password.

#python

# !pip install psycopg2

# Connect to the PostgreSQL database (should be real port number)
conn = psycopg2.connect(
    dbname="Surkov_works",
    user="your_username",
    password="your_password",
    host="your_host",
    port="5432"
)

# Create a cursor object
cur = conn.cursor()
#This script will create a PostgreSQL table with restricted fields for clients, specifically for storing nickname and password.

#python

# !pip install psycopg2

# Connect to the PostgreSQL database (should be real port number)
conn = psycopg2.connect(
    dbname="Surkov_works",
    user="your_username",
    password="your_password",
    host="127.0.0.1", #local_host",
    port="5432"
)

# Create a cursor object
cur = conn.cursor()

# Create a table with restricted fields for client data (nickname and password)
cur.execute("""
    CREATE TABLE IF NOT EXISTS clients (
        client_id SERIAL PRIMARY KEY,
        nickname TEXT,
        password TEXT
    )
""")

# Commit the changes
conn.commit()

# Close the cursor and connection
cur.close()
conn.close()

print("PostgreSQL database table 'clients' created with restricted fields nickname and password.")
#

#Script 2: Add New Clients with Limited Information, Check if New or Returning, and Handle Description of Client's Problem**
#This script will add new clients with limited information (nickname and password), check if the client is new or returning, and prompt for a description of the client's problem.

#python
import psycopg2
import uuid

# Connect to the PostgreSQL database
conn = psycopg2.connect(
    dbname="Surkov_works",
    user="your_username",
    password="your_password",
    host="your_host",
    port="your_port"
)

# Create a cursor object
cur = conn.cursor()

# Get nickname and password from the client
nickname = input("Enter your nickname: ")
password = input("Enter your password: ")

# Check if the client exists in the database
cur.execute("SELECT client_id FROM clients WHERE nickname = %s", (nickname,))
existing_client = cur.fetchone()

if existing_client:
    print(f"Welcome back, {nickname}!")
    # Add more logic for returning clients if needed
else:
    # Insert the new client's limited data into the database
    cur.execute("INSERT INTO clients (nickname, password) VALUES (%s, %s)", (nickname, password))
    print("New client added successfully.")

    # Ask for the client's problem description
    problem_description = input("Describe your problem: ") #пока инпутом
    # Process and store the problem description as needed

# Commit the transaction
conn.commit()

# Close the cursor and connection
cur.close()
conn.close()
        # nickname TEXT,
        # password TEXT
  #)


# Commit the changes
conn.commit()

# Close the cursor and connection
cur.close()
conn.close()

print("PostgreSQL database table 'clients' created with restricted fields.")
#

#Script 2: Add New Clients with Limited Information, Check if New or Returning, and Handle Description of Client's Problem**
#This script will add new clients with limited information (nickname and password), check if the client is new or returning, and prompt for a description of the client's problem.

#python
import psycopg2
import uuid

# Connect to the PostgreSQL database
conn = psycopg2.connect(
    dbname="Surkov_works",
    user="your_username",
    password="your_password",
    host="127.0.0.1",
    port="5432"
)

# Create a cursor object
cur = conn.cursor()

# Get nickname and password from the client
nickname = input("Enter your nickname: ")
password = input("Enter your password: ")

# Check if the client exists in the database
cur.execute("SELECT client_id FROM clients WHERE nickname = %s", (nickname,))
existing_client = cur.fetchone()

if existing_client:
    print(f"Welcome back, {nickname}!")
    # Add more logic for returning clients if needed
else:
    # Insert the new client's limited data into the database
    cur.execute("INSERT INTO clients (nickname, password) VALUES (%s, %s)", (nickname, password))
    print("New client added successfully.")

    # Ask for the client's problem description
    problem_description = input("Describe your problem: ")
    # Process and store the problem description as needed

# Commit the transaction
conn.commit()

# Close the cursor and connection
cur.close()
conn.close()
#
#  nickname TEXT,
#  password TEXT


# Commit the changes
conn.commit()

# Close the cursor and connection
cur.close()
conn.close()

print("PostgreSQL database table 'clients' created with restricted fields nickname and password.")
#

#Script 2: Add New Clients with Limited Information, Check if New or Returning, and Handle Description of Client's Problem**
#This script will add new clients with limited information (nickname and password), check if the client is new or returning, and prompt for a description of the client's problem.

#python
import psycopg2
import uuid

# Connect to the PostgreSQL database
conn = psycopg2.connect(
    dbname="your_dbname",
    user="your_username",
    password="your_password",
    host="5432",
    port="your_port"
)

# Create a cursor object
cur = conn.cursor()

# Get nickname and password from the client
nickname = input("Enter your nickname: ")
password = input("Enter your password: ")

# Check if the client exists in the database
cur.execute("SELECT client_id FROM clients WHERE nickname = %s", (nickname,))
existing_client = cur.fetchone()

if existing_client:
    print(f"Welcome back, {nickname}!")
    # Add more logic for returning clients if needed
else:
    # Insert the new client's limited data into the database
    cur.execute("INSERT INTO clients (nickname, password) VALUES (%s, %s)", (nickname, password))
    print("New client added successfully.")

    # Ask for the client's problem description
    problem_description = input("Describe your problem: ")
    # Process and store the problem description as needed

# Commit the transaction
conn.commit()

# Close the cursor and connection
cur.close()
conn.close()
#
